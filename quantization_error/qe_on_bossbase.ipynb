# %%
# %load_ext autoreload
# %autoreload 2

import sys
sys.path.append("../Tools/")
sys.path.append("../iclr_17_compression/")
from simulate_qe import apply_qe_to_bossbase_img
from my_utils import plot_np_array
import numpy as np
import matplotlib.pyplot as plt

model_path = "../iclr_17_compression/checkpoints/baseline/iter_1590000.pth.tar"
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
p = 0.25 # insertion at 1.5 bpc
precover_folder_path = "../JIN_SRNet/BossBase-1.01-precover/"
idx = 1000
psnr, diff, modification_rate = apply_qe_to_bossbase_img(precover_folder_path,model_path,idx,p,plot_cover_stego=True,plot_diff=True,figsize=(20,10))

print("psnr:",psnr)
print("modification rate:",modification_rate)
# Out:
# psnr: 75.899
# modification rate: 7.62939453125e-06
